# %% [markdown]
# #Multi-Layer Perceptron (MLP) for Handwritten Digit Recognition: Use the MNIST dataset to
# train a Multi-Layer Perceptron using a deep learning library like TensorFlow or PyTorch. Include
# input, hidden, and output layers with activation functions, and evaluate the accuracy.

# %%
import tensorflow as tf
from tensorflow.keras import layers , models

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.mnist.load_data()
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Normalize pixel values (0–255) → (0–1)
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
x_train.shape
# Out:
# (60000, 784)

# %%
y_train.shape
# Out:
# (60000,)

# %%
# Flatten 28x28 images into 784-dimensional vectors
x_train = x_train.reshape(-1, 784)
x_test = x_test.reshape(-1, 784)

# %%
# Build the MLP model
model = models.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),  # Input + Hidden layer 1
    layers.Dense(64, activation='relu'),                      # Hidden layer 2
    layers.Dense(10, activation='softmax')                    # Output layer (10 classes)
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history=model.fit(x_train,y_train,epochs=5,batch_size=125,validation_split=0.1)
# Out:
# Epoch 1/5
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8250 - loss: 0.6337 - val_accuracy: 0.9608 - val_loss: 0.1401
# Epoch 2/5
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9551 - loss: 0.1531 - val_accuracy: 0.9712 - val_loss: 0.1020
# Epoch 3/5
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - accuracy: 0.9693 - loss: 0.1011 - val_accuracy: 0.9720 - val_loss: 0.0910
# Epoch 4/5
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9777 - loss: 0.0761 - val_accuracy: 0.9773 - val_loss: 0.0828
# Epoch 5/5
# 432/432 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9846 - loss: 0.0537 - val_accuracy: 0.9782 - val_loss: 0.0771

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"\n✅ Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9758 - loss: 0.0874
#
# ✅ Test Accuracy: 97.72%
